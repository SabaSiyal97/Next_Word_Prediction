# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer  # Changed import to use Keras from TensorFlow
from tensorflow.keras.preprocessing.sequence import pad_sequences  # Corrected import for pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
#read dataset
with open('urdu Dataset.txt','r',encoding='utf-8') as file:
    text=file.read()

# %%
#Tokenizer process
tokenizer=Tokenizer()
#fit
tokenizer.fit_on_texts([text])
#assign length of word index
total_words=len(tokenizer.word_index)+1

# %%
tokenizer.word_index
# Out:
# {'اور': 1,
#  'کے': 2,
#  'کی': 3,
#  'میں': 4,
#  'انٹرنیٹ': 5,
#  'کو': 6,
#  'ہے۔': 7,
#  'نوجوانوں': 8,
#  'پر': 9,
#  'ہیں۔': 10,
#  'صحت': 11,
#  'نے': 12,
#  'سے': 13,
#  'ذہنی': 14,
#  'کا': 15,
#  'ایک': 16,
#  'اس': 17,
#  'بھی': 18,
#  'کر': 19,
#  'زندگی': 20,
#  'نوجوان': 21,
#  'ان': 22,
#  'جسمانی': 23,
#  'اثرات': 24,
#  'منفی': 25,
#  'یہ': 26,
#  'کہ': 27,
#  'لیے': 28,
#  'ہو': 29,
#  'ہے': 30,
#  'معلومات': 31,
#  'ہیں': 32,
#  'دیا': 33,
#  'استعمال': 34,
#  'انہیں': 35,
#  'سرگرمیوں': 36,
#  'نئی': 37,
#  'نسل': 38,
#  'دنیا': 39,
#  'صرف': 40,
#  'آن': 41,
#  'لائن': 42,
#  'غلط': 43,
#  'دور': 44,
#  'حصہ': 45,
#  'فراہم': 46,
#  'بہت': 47,
#  'پیدا': 48,
#  'مثبت': 49,
#  'خیالی': 50,
#  'کرنا': 51,
#  'علم': 52,
#  'بنا': 53,
#  'سکتا': 54,
#  'زیادہ': 55,
#  'ویب': 56,
#  'سائٹس': 57,
#  'بارے': 58,
#  'دیتی': 59,
#  'نقصان': 60,
#  'چاہیے': 61,
#  'آج': 62,
#  'جہاں': 63,
#  'بے': 64,
#  'ہیں،': 65,
#  'وہیں': 66,
#  'مشکلات': 67,
#  'طور': 68,
#  'مرتب': 69,
#  'پہلوؤں': 70,
#  'اپنا': 71,
#  'حقیقت': 72,
#  'پہلو': 73,
#  'حاصل': 74,
#  'تخلیقی': 75,
#  'کیا': 76,
#  'مختلف': 77,
#  'متاثر': 78,
#  'سماجی': 79,
#  'وقت': 80,
#  'نظر': 81,
#  'مبتلا': 82,
#  'سوشل': 83,
#  'میڈیا': 84,
#  'کرنے': 85,
#  'ڈپریشن': 86,
#  'انزائٹی': 87,
#  'مسائل': 88,
#  'جاتے': 89,
#  'رویہ': 90,
#  'توازن': 91,
#  'دہ': 92,
#  'لیتے': 93,
#  'کمی': 94,
#  'رہی': 95,
#  'بہتر': 96,
#  'وہ': 97,
#  'جا': 98,
#  'لازمی': 99,
#  'بن': 100,
#  'چکا': 101,
#  'بغیر': 102,
#  'تصور': 103,
#  'ممکن': 104,
#  'نہیں': 105,
#  'رہا۔': 106,
#  'ہماری': 107,
#  'زندگیوں': 108,
#  'شمار': 109,
#  'سہولتیں': 110,
#  'سی': 111,
#  'پیچیدگیاں': 112,
#  'خاص': 113,
#  'گہرے': 114,
#  'ہوئے': 115,
#  'دونوں': 116,
#  'اثر': 117,
#  'ڈالا': 118,
#  'قدر': 119,
#  'شدید': 120,
#  'بعض': 121,
#  'اوقات': 122,
#  'درمیان': 123,
#  'فرق': 124,
#  'مشکل': 125,
#  'جاتا': 126,
#  'تک': 127,
#  'رسائی': 128,
#  'آسان': 129,
#  'کلک': 130,
#  'کسی': 131,
#  'حصے': 132,
#  'تعلیم،': 133,
#  'تحقیق،': 134,
#  'صلاحیتوں': 135,
#  'فروغ': 136,
#  'دینے': 137,
#  'حوالے': 138,
#  'نیا': 139,
#  'پلیٹ': 140,
#  'فارم': 141,
#  'تعلیمی': 142,
#  'مواد،': 143,
#  'کورسز،': 144,
#  'لیکچرز': 145,
#  'بدولت': 146,
#  'اپنے': 147,
#  'اضافے': 148,
#  'شعبوں': 149,
#  'مہارت': 150,
#  'سکتے': 151,
#  'تاہم،': 152,
#  'رابطوں': 153,
#  'مثلاً': 154,
#  'فیس': 155,
#  'بک،': 156,
#  'انسٹاگرام': 157,
#  'ٹک': 158,
#  'ٹاک': 159,
#  'وغیرہ': 160,
#  'کرتے': 161,
#  'آنے': 162,
#  'والی': 163,
#  'مصنوعی': 164,
#  'عکاسی': 165,
#  'اپنی': 166,
#  'احساس': 167,
#  'کمتری': 168,
#  'دوسروں': 169,
#  'کامیابی،': 170,
#  'خوشی': 171,
#  'خوبصورتی': 172,
#  'دیکھ': 173,
#  'خود': 174,
#  'کمتر': 175,
#  'محسوس': 176,
#  'لگتے': 177,
#  'جس': 178,
#  'جیسی': 179,
#  'بیماریاں': 180,
#  'جنم': 181,
#  'لیتی': 182,
#  'گیمنگ،': 183,
#  'ویڈیوز،': 184,
#  'انٹرٹینمنٹ': 185,
#  'قید': 186,
#  'تر': 187,
#  'گزارتے': 188,
#  'حقیقی': 189,
#  'کنارہ': 190,
#  'کش': 191,
#  'شخصیت': 192,
#  'عدم': 193,
#  'کرتا': 194,
#  'خاندانی': 195,
#  'تعلقات': 196,
#  'سامنا': 197,
#  'پڑتا': 198,
#  'دستیاب': 199,
#  'ثابت': 200,
#  'سکتی': 201,
#  'بلاگز': 202,
#  'گمراہ': 203,
#  'کن': 204,
#  'جاتی': 205,
#  'جنہیں': 206,
#  'سچ': 207,
#  'سمجھ': 208,
#  'خیالات': 209,
#  'الجھن': 210,
#  'مزید': 211,
#  'برآں،': 212,
#  'دھوکہ': 213,
#  'دہی': 214,
#  'سائبر': 215,
#  'بلیئنگ': 216,
#  'جیسے': 217,
#  'جو': 218,
#  'ڈالتے': 219,
#  'بڑا': 220,
#  'پہلے': 221,
#  'ادوار': 222,
#  'کھیل': 223,
#  'کود': 224,
#  'دیگر': 225,
#  'تھے،': 226,
#  'لیکن': 227,
#  'اب': 228,
#  'گیجٹس': 229,
#  'سست': 230,
#  'کاہل': 231,
#  'نہ': 232,
#  'بلکہ': 233,
#  'خراب': 234,
#  'ورزش': 235,
#  'امکانات': 236,
#  'بڑھ': 237,
#  'بنانے': 238,
#  'ضروری': 239,
#  'والدین': 240,
#  'اساتذہ': 241,
#  'عادات': 242,
#  'رکھیں': 243,
#  'صحیح': 244,
#  'آگاہ': 245,
#  'کریں۔': 246,
#  'گیمنگ': 247,
#  'بجائے': 248,
#  'کتابیں': 249,
#  'پڑھنے،': 250,
#  'مشاغل': 251,
#  'لینے': 252,
#  'ترغیب': 253,
#  'دی': 254,
#  'جائے۔': 255,
#  'علاوہ،': 256,
#  'حکومت': 257,
#  'ایسے': 258,
#  'قوانین': 259,
#  'بنائے': 260,
#  'جن': 261,
#  'بچایا': 262,
#  'سکے۔': 263,
#  'نتیجہ': 264,
#  'پر،': 265,
#  'خزانہ': 266,
#  'ہے،': 267,
#  'رہے': 268,
#  'شعور': 269,
#  'ہونا': 270,
#  'اسے': 271,
#  'تعمیری': 272,
#  'مقاصد': 273,
#  'چاہیے۔': 274,
#  'متوازن': 275,
#  'ذمہ': 276,
#  'دارانہ': 277,
#  'ہی': 278,
#  'کامیاب': 279,
#  'خوشحال': 280,
#  'گزارنے': 281,
#  'مدد': 282,
#  'دے': 283}

# %%
tokenizer.word_index
# Out:
# {'اور': 1,
#  'کے': 2,
#  'کی': 3,
#  'میں': 4,
#  'انٹرنیٹ': 5,
#  'کو': 6,
#  'ہے۔': 7,
#  'نوجوانوں': 8,
#  'پر': 9,
#  'ہیں۔': 10,
#  'صحت': 11,
#  'نے': 12,
#  'سے': 13,
#  'ذہنی': 14,
#  'کا': 15,
#  'ایک': 16,
#  'اس': 17,
#  'بھی': 18,
#  'کر': 19,
#  'زندگی': 20,
#  'نوجوان': 21,
#  'ان': 22,
#  'جسمانی': 23,
#  'اثرات': 24,
#  'منفی': 25,
#  'یہ': 26,
#  'کہ': 27,
#  'لیے': 28,
#  'ہو': 29,
#  'ہے': 30,
#  'معلومات': 31,
#  'ہیں': 32,
#  'دیا': 33,
#  'استعمال': 34,
#  'انہیں': 35,
#  'سرگرمیوں': 36,
#  'نئی': 37,
#  'نسل': 38,
#  'دنیا': 39,
#  'صرف': 40,
#  'آن': 41,
#  'لائن': 42,
#  'غلط': 43,
#  'دور': 44,
#  'حصہ': 45,
#  'فراہم': 46,
#  'بہت': 47,
#  'پیدا': 48,
#  'مثبت': 49,
#  'خیالی': 50,
#  'کرنا': 51,
#  'علم': 52,
#  'بنا': 53,
#  'سکتا': 54,
#  'زیادہ': 55,
#  'ویب': 56,
#  'سائٹس': 57,
#  'بارے': 58,
#  'دیتی': 59,
#  'نقصان': 60,
#  'چاہیے': 61,
#  'آج': 62,
#  'جہاں': 63,
#  'بے': 64,
#  'ہیں،': 65,
#  'وہیں': 66,
#  'مشکلات': 67,
#  'طور': 68,
#  'مرتب': 69,
#  'پہلوؤں': 70,
#  'اپنا': 71,
#  'حقیقت': 72,
#  'پہلو': 73,
#  'حاصل': 74,
#  'تخلیقی': 75,
#  'کیا': 76,
#  'مختلف': 77,
#  'متاثر': 78,
#  'سماجی': 79,
#  'وقت': 80,
#  'نظر': 81,
#  'مبتلا': 82,
#  'سوشل': 83,
#  'میڈیا': 84,
#  'کرنے': 85,
#  'ڈپریشن': 86,
#  'انزائٹی': 87,
#  'مسائل': 88,
#  'جاتے': 89,
#  'رویہ': 90,
#  'توازن': 91,
#  'دہ': 92,
#  'لیتے': 93,
#  'کمی': 94,
#  'رہی': 95,
#  'بہتر': 96,
#  'وہ': 97,
#  'جا': 98,
#  'لازمی': 99,
#  'بن': 100,
#  'چکا': 101,
#  'بغیر': 102,
#  'تصور': 103,
#  'ممکن': 104,
#  'نہیں': 105,
#  'رہا۔': 106,
#  'ہماری': 107,
#  'زندگیوں': 108,
#  'شمار': 109,
#  'سہولتیں': 110,
#  'سی': 111,
#  'پیچیدگیاں': 112,
#  'خاص': 113,
#  'گہرے': 114,
#  'ہوئے': 115,
#  'دونوں': 116,
#  'اثر': 117,
#  'ڈالا': 118,
#  'قدر': 119,
#  'شدید': 120,
#  'بعض': 121,
#  'اوقات': 122,
#  'درمیان': 123,
#  'فرق': 124,
#  'مشکل': 125,
#  'جاتا': 126,
#  'تک': 127,
#  'رسائی': 128,
#  'آسان': 129,
#  'کلک': 130,
#  'کسی': 131,
#  'حصے': 132,
#  'تعلیم،': 133,
#  'تحقیق،': 134,
#  'صلاحیتوں': 135,
#  'فروغ': 136,
#  'دینے': 137,
#  'حوالے': 138,
#  'نیا': 139,
#  'پلیٹ': 140,
#  'فارم': 141,
#  'تعلیمی': 142,
#  'مواد،': 143,
#  'کورسز،': 144,
#  'لیکچرز': 145,
#  'بدولت': 146,
#  'اپنے': 147,
#  'اضافے': 148,
#  'شعبوں': 149,
#  'مہارت': 150,
#  'سکتے': 151,
#  'تاہم،': 152,
#  'رابطوں': 153,
#  'مثلاً': 154,
#  'فیس': 155,
#  'بک،': 156,
#  'انسٹاگرام': 157,
#  'ٹک': 158,
#  'ٹاک': 159,
#  'وغیرہ': 160,
#  'کرتے': 161,
#  'آنے': 162,
#  'والی': 163,
#  'مصنوعی': 164,
#  'عکاسی': 165,
#  'اپنی': 166,
#  'احساس': 167,
#  'کمتری': 168,
#  'دوسروں': 169,
#  'کامیابی،': 170,
#  'خوشی': 171,
#  'خوبصورتی': 172,
#  'دیکھ': 173,
#  'خود': 174,
#  'کمتر': 175,
#  'محسوس': 176,
#  'لگتے': 177,
#  'جس': 178,
#  'جیسی': 179,
#  'بیماریاں': 180,
#  'جنم': 181,
#  'لیتی': 182,
#  'گیمنگ،': 183,
#  'ویڈیوز،': 184,
#  'انٹرٹینمنٹ': 185,
#  'قید': 186,
#  'تر': 187,
#  'گزارتے': 188,
#  'حقیقی': 189,
#  'کنارہ': 190,
#  'کش': 191,
#  'شخصیت': 192,
#  'عدم': 193,
#  'کرتا': 194,
#  'خاندانی': 195,
#  'تعلقات': 196,
#  'سامنا': 197,
#  'پڑتا': 198,
#  'دستیاب': 199,
#  'ثابت': 200,
#  'سکتی': 201,
#  'بلاگز': 202,
#  'گمراہ': 203,
#  'کن': 204,
#  'جاتی': 205,
#  'جنہیں': 206,
#  'سچ': 207,
#  'سمجھ': 208,
#  'خیالات': 209,
#  'الجھن': 210,
#  'مزید': 211,
#  'برآں،': 212,
#  'دھوکہ': 213,
#  'دہی': 214,
#  'سائبر': 215,
#  'بلیئنگ': 216,
#  'جیسے': 217,
#  'جو': 218,
#  'ڈالتے': 219,
#  'بڑا': 220,
#  'پہلے': 221,
#  'ادوار': 222,
#  'کھیل': 223,
#  'کود': 224,
#  'دیگر': 225,
#  'تھے،': 226,
#  'لیکن': 227,
#  'اب': 228,
#  'گیجٹس': 229,
#  'سست': 230,
#  'کاہل': 231,
#  'نہ': 232,
#  'بلکہ': 233,
#  'خراب': 234,
#  'ورزش': 235,
#  'امکانات': 236,
#  'بڑھ': 237,
#  'بنانے': 238,
#  'ضروری': 239,
#  'والدین': 240,
#  'اساتذہ': 241,
#  'عادات': 242,
#  'رکھیں': 243,
#  'صحیح': 244,
#  'آگاہ': 245,
#  'کریں۔': 246,
#  'گیمنگ': 247,
#  'بجائے': 248,
#  'کتابیں': 249,
#  'پڑھنے،': 250,
#  'مشاغل': 251,
#  'لینے': 252,
#  'ترغیب': 253,
#  'دی': 254,
#  'جائے۔': 255,
#  'علاوہ،': 256,
#  'حکومت': 257,
#  'ایسے': 258,
#  'قوانین': 259,
#  'بنائے': 260,
#  'جن': 261,
#  'بچایا': 262,
#  'سکے۔': 263,
#  'نتیجہ': 264,
#  'پر،': 265,
#  'خزانہ': 266,
#  'ہے،': 267,
#  'رہے': 268,
#  'شعور': 269,
#  'ہونا': 270,
#  'اسے': 271,
#  'تعمیری': 272,
#  'مقاصد': 273,
#  'چاہیے۔': 274,
#  'متوازن': 275,
#  'ذمہ': 276,
#  'دارانہ': 277,
#  'ہی': 278,
#  'کامیاب': 279,
#  'خوشحال': 280,
#  'گزارنے': 281,
#  'مدد': 282,
#  'دے': 283}

# %%
#n-gram model
#declare n-grams
input_sequences=[]
#splitting from \n
for line in text.split('\n'):
    #getting tokens
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1,len(token_list)):
       n_gram_sequence = token_list[:i+1]
       input_sequences.append(n_gram_sequence)

# %%
input_sequences
# Out:
# [[5, 1],
#  [5, 1, 37],
#  [5, 1, 37, 38],
#  [5, 1, 37, 38, 3],
#  [5, 1, 37, 38, 3, 14],
#  [5, 1, 37, 38, 3, 14, 11],
#  [5, 1, 37, 38, 3, 14, 11, 9],
#  [5, 1, 37, 38, 3, 14, 11, 9, 24],
#  [62, 2],
#  [62, 2, 44],
#  [62, 2, 44, 4],
#  [62, 2, 44, 4, 5],
#  [62, 2, 44, 4, 5, 20],
#  [62, 2, 44, 4, 5, 20, 15],
#  [62, 2, 44, 4, 5, 20, 15, 16],
#  [62, 2, 44, 4, 5, 20, 15, 16, 99],
#  [62, 2, 44, 4, 5, 20, 15, 16, 99, 45],
#  [62, 2, 44, 4, 5, 20, 15, 16, 99, 45, 100],
#  [62, 2, 44, 4, 5, 20, 15, 16, 99, 45, 100, 101],
#  [62, 2, 44, 4, 5, 20, 15, 16, 99, 45, 100, 101, 7],
#  [62, 2, 44, 4, 5, 20, 15, 16, 99, 45, 100, 101, 7, 17],
#  [62, 2, 44, 4, 5, 20, 15, 16, 99, 45, 100, 101, 7, 17, 2],
#  [62, 2, 44, 4, 5, 20, 15, 16, 99, 45, 100, 101, 7, 17, 2, 102],
#  [62, 2, 44, 4, 5, 20, 15, 16, 99, 45, 100, 101, 7, 17, 2, 102, 20],
#  [62, 2, 44, 4, 5, 20, 15, 16, 99, 45, 100, 101, 7, 17, 2, 102, 20, 15],
#  [62, 2, 44, 4, 5, 20, 15, 16, 99, 45, 100, 101, 7, 17, 2, 102, 20, 15, 103],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17,
#   119],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17,
#   119,
#   120],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17,
#   119,
#   120,
#   32],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17,
#   119,
#   120,
#   32,
#   27],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17,
#   119,
#   120,
#   32,
#   27,
#   121],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17,
#   119,
#   120,
#   32,
#   27,
#   121,
#   122],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17,
#   119,
#   120,
#   32,
#   27,
#   121,
#   122,
#   8],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17,
#   119,
#   120,
#   32,
#   27,
#   121,
#   122,
#   8,
#   2],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17,
#   119,
#   120,
#   32,
#   27,
#   121,
#   122,
#   8,
#   2,
#   28],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17,
#   119,
#   120,
#   32,
#   27,
#   121,
#   122,
#   8,
#   2,
#   28,
#   72],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17,
#   119,
#   120,
#   32,
#   27,
#   121,
#   122,
#   8,
#   2,
#   28,
#   72,
#   1],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17,
#   119,
#   120,
#   32,
#   27,
#   121,
#   122,
#   8,
#   2,
#   28,
#   72,
#   1,
#   50],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17,
#   119,
#   120,
#   32,
#   27,
#   121,
#   122,
#   8,
#   2,
#   28,
#   72,
#   1,
#   50,
#   39],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17,
#   119,
#   120,
#   32,
#   27,
#   121,
#   122,
#   8,
#   2,
#   28,
#   72,
#   1,
#   50,
#   39,
#   2],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17,
#   119,
#   120,
#   32,
#   27,
#   121,
#   122,
#   8,
#   2,
#   28,
#   72,
#   1,
#   50,
#   39,
#   2,
#   123],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17,
#   119,
#   120,
#   32,
#   27,
#   121,
#   122,
#   8,
#   2,
#   28,
#   72,
#   1,
#   50,
#   39,
#   2,
#   123,
#   124],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17,
#   119,
#   120,
#   32,
#   27,
#   121,
#   122,
#   8,
#   2,
#   28,
#   72,
#   1,
#   50,
#   39,
#   2,
#   123,
#   124,
#   51],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17,
#   119,
#   120,
#   32,
#   27,
#   121,
#   122,
#   8,
#   2,
#   28,
#   72,
#   1,
#   50,
#   39,
#   2,
#   123,
#   124,
#   51,
#   125],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17,
#   119,
#   120,
#   32,
#   27,
#   121,
#   122,
#   8,
#   2,
#   28,
#   72,
#   1,
#   50,
#   39,
#   2,
#   123,
#   124,
#   51,
#   125,
#   29],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17,
#   119,
#   120,
#   32,
#   27,
#   121,
#   122,
#   8,
#   2,
#   28,
#   72,
#   1,
#   50,
#   39,
#   2,
#   123,
#   124,
#   51,
#   125,
#   29,
#   126],
#  [62,
#   2,
#   44,
#   4,
#   5,
#   20,
#   15,
#   16,
#   99,
#   45,
#   100,
#   101,
#   7,
#   17,
#   2,
#   102,
#   20,
#   15,
#   103,
#   18,
#   104,
#   105,
#   106,
#   5,
#   12,
#   63,
#   107,
#   108,
#   4,
#   64,
#   109,
#   110,
#   46,
#   3,
#   65,
#   66,
#   17,
#   12,
#   47,
#   111,
#   112,
#   1,
#   67,
#   18,
#   48,
#   3,
#   10,
#   113,
#   68,
#   9,
#   37,
#   38,
#   9,
#   5,
#   2,
#   114,
#   24,
#   69,
#   115,
#   10,
#   8,
#   3,
#   14,
#   11,
#   9,
#   5,
#   2,
#   49,
#   1,
#   25,
#   116,
#   70,
#   12,
#   71,
#   117,
#   118,
#   7,
#   26,
#   24,
#   17,
#   119,
#   120,
#   32,
#   27,
#   121,
#   122,
#   8,
#   2,
#   28,
#   72,
#   1,
#   50,
#   39,
#   2,
#   123,
#   124,
#   51,
#   125,
#   29,
#   126,
#   7],
#  [5, 15],
#  [5, 15, 16],
#  [5, 15, 16, 49],
#  [5, 15, 16, 49, 73],
#  [5, 15, 16, 49, 73, 26],
#  [5, 15, 16, 49, 73, 26, 30],
#  [5, 15, 16, 49, 73, 26, 30, 27],
#  [5, 15, 16, 49, 73, 26, 30, 27, 17],
#  [5, 15, 16, 49, 73, 26, 30, 27, 17, 12],
#  [5, 15, 16, 49, 73, 26, 30, 27, 17, 12, 52],
#  [5, 15, 16, 49, 73, 26, 30, 27, 17, 12, 52, 1],
#  [5, 15, 16, 49, 73, 26, 30, 27, 17, 12, 52, 1, 31],
#  [5, 15, 16, 49, 73, 26, 30, 27, 17, 12, 52, 1, 31, 127],
#  [5, 15, 16, 49, 73, 26, 30, 27, 17, 12, 52, 1, 31, 127, 128],
#  [5, 15, 16, 49, 73, 26, 30, 27, 17, 12, 52, 1, 31, 127, 128, 6],
#  [5, 15, 16, 49, 73, 26, 30, 27, 17, 12, 52, 1, 31, 127, 128, 6, 129],
#  [5, 15, 16, 49, 73, 26, 30, 27, 17, 12, 52, 1, 31, 127, 128, 6, 129, 53],
#  [5, 15, 16, 49, 73, 26, 30, 27, 17, 12, 52, 1, 31, 127, 128, 6, 129, 53, 33],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16,
#   139],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16,
#   139,
#   140],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16,
#   139,
#   140,
#   141],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16,
#   139,
#   140,
#   141,
#   46],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16,
#   139,
#   140,
#   141,
#   46,
#   76],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16,
#   139,
#   140,
#   141,
#   46,
#   76,
#   7],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16,
#   139,
#   140,
#   141,
#   46,
#   76,
#   7,
#   41],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16,
#   139,
#   140,
#   141,
#   46,
#   76,
#   7,
#   41,
#   42],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16,
#   139,
#   140,
#   141,
#   46,
#   76,
#   7,
#   41,
#   42,
#   142],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16,
#   139,
#   140,
#   141,
#   46,
#   76,
#   7,
#   41,
#   42,
#   142,
#   143],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16,
#   139,
#   140,
#   141,
#   46,
#   76,
#   7,
#   41,
#   42,
#   142,
#   143,
#   144],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16,
#   139,
#   140,
#   141,
#   46,
#   76,
#   7,
#   41,
#   42,
#   142,
#   143,
#   144,
#   1],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16,
#   139,
#   140,
#   141,
#   46,
#   76,
#   7,
#   41,
#   42,
#   142,
#   143,
#   144,
#   1,
#   145],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16,
#   139,
#   140,
#   141,
#   46,
#   76,
#   7,
#   41,
#   42,
#   142,
#   143,
#   144,
#   1,
#   145,
#   3],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16,
#   139,
#   140,
#   141,
#   46,
#   76,
#   7,
#   41,
#   42,
#   142,
#   143,
#   144,
#   1,
#   145,
#   3,
#   146],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16,
#   139,
#   140,
#   141,
#   46,
#   76,
#   7,
#   41,
#   42,
#   142,
#   143,
#   144,
#   1,
#   145,
#   3,
#   146,
#   21],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16,
#   139,
#   140,
#   141,
#   46,
#   76,
#   7,
#   41,
#   42,
#   142,
#   143,
#   144,
#   1,
#   145,
#   3,
#   146,
#   21,
#   147],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16,
#   139,
#   140,
#   141,
#   46,
#   76,
#   7,
#   41,
#   42,
#   142,
#   143,
#   144,
#   1,
#   145,
#   3,
#   146,
#   21,
#   147,
#   52],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16,
#   139,
#   140,
#   141,
#   46,
#   76,
#   7,
#   41,
#   42,
#   142,
#   143,
#   144,
#   1,
#   145,
#   3,
#   146,
#   21,
#   147,
#   52,
#   4],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16,
#   139,
#   140,
#   141,
#   46,
#   76,
#   7,
#   41,
#   42,
#   142,
#   143,
#   144,
#   1,
#   145,
#   3,
#   146,
#   21,
#   147,
#   52,
#   4,
#   148],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
#   16,
#   139,
#   140,
#   141,
#   46,
#   76,
#   7,
#   41,
#   42,
#   142,
#   143,
#   144,
#   1,
#   145,
#   3,
#   146,
#   21,
#   147,
#   52,
#   4,
#   148,
#   1],
#  [5,
#   15,
#   16,
#   49,
#   73,
#   26,
#   30,
#   27,
#   17,
#   12,
#   52,
#   1,
#   31,
#   127,
#   128,
#   6,
#   129,
#   53,
#   33,
#   7,
#   62,
#   15,
#   21,
#   40,
#   16,
#   130,
#   9,
#   39,
#   2,
#   131,
#   18,
#   132,
#   3,
#   31,
#   74,
#   19,
#   54,
#   7,
#   133,
#   134,
#   1,
#   75,
#   135,
#   6,
#   136,
#   137,
#   2,
#   138,
#   13,
#   5,
#   12,
#   8,
#   6,
# ...
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14,
#   1],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14,
#   1,
#   23],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14,
#   1,
#   23,
#   11],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14,
#   1,
#   23,
#   11,
#   6],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14,
#   1,
#   23,
#   11,
#   6,
#   96],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14,
#   1,
#   23,
#   11,
#   6,
#   96,
#   53],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14,
#   1,
#   23,
#   11,
#   6,
#   96,
#   53,
#   54],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14,
#   1,
#   23,
#   11,
#   6,
#   96,
#   53,
#   54,
#   30],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14,
#   1,
#   23,
#   11,
#   6,
#   96,
#   53,
#   54,
#   30,
#   1],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14,
#   1,
#   23,
#   11,
#   6,
#   96,
#   53,
#   54,
#   30,
#   1,
#   35],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14,
#   1,
#   23,
#   11,
#   6,
#   96,
#   53,
#   54,
#   30,
#   1,
#   35,
#   16],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14,
#   1,
#   23,
#   11,
#   6,
#   96,
#   53,
#   54,
#   30,
#   1,
#   35,
#   16,
#   279],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14,
#   1,
#   23,
#   11,
#   6,
#   96,
#   53,
#   54,
#   30,
#   1,
#   35,
#   16,
#   279,
#   1],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14,
#   1,
#   23,
#   11,
#   6,
#   96,
#   53,
#   54,
#   30,
#   1,
#   35,
#   16,
#   279,
#   1,
#   280],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14,
#   1,
#   23,
#   11,
#   6,
#   96,
#   53,
#   54,
#   30,
#   1,
#   35,
#   16,
#   279,
#   1,
#   280,
#   20],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14,
#   1,
#   23,
#   11,
#   6,
#   96,
#   53,
#   54,
#   30,
#   1,
#   35,
#   16,
#   279,
#   1,
#   280,
#   20,
#   281],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14,
#   1,
#   23,
#   11,
#   6,
#   96,
#   53,
#   54,
#   30,
#   1,
#   35,
#   16,
#   279,
#   1,
#   280,
#   20,
#   281,
#   4],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14,
#   1,
#   23,
#   11,
#   6,
#   96,
#   53,
#   54,
#   30,
#   1,
#   35,
#   16,
#   279,
#   1,
#   280,
#   20,
#   281,
#   4,
#   282],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14,
#   1,
#   23,
#   11,
#   6,
#   96,
#   53,
#   54,
#   30,
#   1,
#   35,
#   16,
#   279,
#   1,
#   280,
#   20,
#   281,
#   4,
#   282,
#   283],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14,
#   1,
#   23,
#   11,
#   6,
#   96,
#   53,
#   54,
#   30,
#   1,
#   35,
#   16,
#   279,
#   1,
#   280,
#   20,
#   281,
#   4,
#   282,
#   283,
#   54],
#  [264,
#   2,
#   68,
#   265,
#   5,
#   63,
#   8,
#   2,
#   28,
#   52,
#   1,
#   31,
#   15,
#   266,
#   267,
#   66,
#   17,
#   2,
#   64,
#   98,
#   34,
#   13,
#   22,
#   3,
#   14,
#   11,
#   9,
#   25,
#   24,
#   18,
#   69,
#   29,
#   268,
#   10,
#   8,
#   6,
#   5,
#   2,
#   49,
#   1,
#   25,
#   70,
#   15,
#   269,
#   270,
#   61,
#   1,
#   271,
#   40,
#   272,
#   273,
#   2,
#   28,
#   34,
#   51,
#   274,
#   16,
#   275,
#   1,
#   276,
#   277,
#   90,
#   278,
#   37,
#   38,
#   3,
#   14,
#   1,
#   23,
#   11,
#   6,
#   96,
#   53,
#   54,
#   30,
#   1,
#   35,
#   16,
#   279,
#   1,
#   280,
#   20,
#   281,
#   4,
#   282,
#   283,
#   54,
#   7]]

# %%
#checking token sentence
sentence_token = input_sequences[10]
sentence=[]
for token in sentence_token:
    sentence.append(list((tokenizer.word_index).keys()) [list((tokenizer.word_index).values()).index(token)])
print(sentence)
# Out:
# ['آج', 'کے', 'دور', 'میں']

# %%
#padding
#maximum sentence length'
max_sequence_len = max([len(seq) for  seq in input_sequences])
#input sequences
input_sequences= np.array(pad_sequences(input_sequences,maxlen=max_sequence_len,padding='pre'))

# %%
input_sequences
# Out:
# array([[  0,   0,   0, ...,   0,   5,   1],
#        [  0,   0,   0, ...,   5,   1,  37],
#        [  0,   0,   0, ...,   1,  37,  38],
#        ...,
#        [  0,   0,   0, ...,   4, 282, 283],
#        [  0,   0,   0, ..., 282, 283,  54],
#        [  0,   0,   0, ..., 283,  54,   7]])

# %%
X = input_sequences[:, :-1]
y = input_sequences[:, -1]

# %%
X.shape
# Out:
# (717, 100)

# %%
y.shape
# Out:
# (717,)

# %%
y=np.array(tf.keras.utils.to_categorical(y,num_classes=total_words))

# %%
#create mode;
model=Sequential()
model.add(Embedding(total_words,100,input_length=max_sequence_len-1))
model.add(LSTM(150))
model.add(Dense(total_words,activation='softmax'))

from tensorflow.keras import backend as K
K.clear_session()
# Out:
# WARNING:tensorflow:From c:\Users\PMLS\anaconda3\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# c:\Users\PMLS\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
#compile the model
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
#fit the model
model.fit(X,y,epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.0312 - loss: 5.6189
# Epoch 2/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.0371 - loss: 5.1703
# Epoch 3/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.0521 - loss: 5.0686
# Epoch 4/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.0462 - loss: 5.0181
# Epoch 5/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.0424 - loss: 4.9992
# Epoch 6/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.0422 - loss: 4.9528
# Epoch 7/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.0612 - loss: 4.8600
# Epoch 8/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.0646 - loss: 4.8115
# Epoch 9/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.0800 - loss: 4.5879
# Epoch 10/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.1114 - loss: 4.4177
# Epoch 11/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.1418 - loss: 4.1524
# Epoch 12/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.1843 - loss: 3.8958
# Epoch 13/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.2267 - loss: 3.6829
# Epoch 14/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.2895 - loss: 3.4155
# Epoch 15/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.3062 - loss: 3.2368
# Epoch 16/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.3646 - loss: 2.9248
# Epoch 17/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.4343 - loss: 2.7214
# Epoch 18/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.4371 - loss: 2.5446
# Epoch 19/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.5033 - loss: 2.4084
# Epoch 20/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5648 - loss: 2.1076
# Epoch 21/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.6288 - loss: 1.9277
# Epoch 22/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.6841 - loss: 1.7678
# Epoch 23/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.7325 - loss: 1.6589
# Epoch 24/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7996 - loss: 1.4652
# Epoch 25/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8079 - loss: 1.3496
# Epoch 26/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8499 - loss: 1.2081
# Epoch 27/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9037 - loss: 1.1028
# Epoch 28/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9196 - loss: 1.0216
# Epoch 29/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9333 - loss: 0.9264
# Epoch 30/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9139 - loss: 0.8992
# Epoch 31/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9327 - loss: 0.8272
# Epoch 32/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9493 - loss: 0.7456
# Epoch 33/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9599 - loss: 0.6855
# Epoch 34/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9747 - loss: 0.6200
# Epoch 35/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9706 - loss: 0.5755
# Epoch 36/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9753 - loss: 0.5285
# Epoch 37/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9788 - loss: 0.5123
# Epoch 38/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9854 - loss: 0.4506
# Epoch 39/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9852 - loss: 0.4191
# Epoch 40/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9848 - loss: 0.3978
# Epoch 41/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9886 - loss: 0.3753
# Epoch 42/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9828 - loss: 0.3618
# Epoch 43/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9911 - loss: 0.3363
# Epoch 44/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9814 - loss: 0.3186
# Epoch 45/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9882 - loss: 0.2880
# Epoch 46/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9886 - loss: 0.2788
# Epoch 47/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9898 - loss: 0.2611
# Epoch 48/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9939 - loss: 0.2452
# Epoch 49/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9890 - loss: 0.2306
# Epoch 50/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9916 - loss: 0.2247
# Epoch 51/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9921 - loss: 0.2218
# Epoch 52/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9938 - loss: 0.2053
# Epoch 53/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9898 - loss: 0.2005
# Epoch 54/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9944 - loss: 0.1788
# Epoch 55/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9940 - loss: 0.1713
# Epoch 56/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9892 - loss: 0.1705
# Epoch 57/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9926 - loss: 0.1547
# Epoch 58/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9961 - loss: 0.1581
# Epoch 59/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9930 - loss: 0.1408
# Epoch 60/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9943 - loss: 0.1401
# Epoch 61/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9967 - loss: 0.1300
# Epoch 62/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9957 - loss: 0.1304
# Epoch 63/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9895 - loss: 0.1336
# Epoch 64/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9951 - loss: 0.1116
# Epoch 65/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9884 - loss: 0.1222
# Epoch 66/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9938 - loss: 0.1113
# Epoch 67/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9933 - loss: 0.1113
# Epoch 68/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9934 - loss: 0.1052
# Epoch 69/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9959 - loss: 0.0960
# Epoch 70/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9905 - loss: 0.1032
# Epoch 71/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9980 - loss: 0.0889
# Epoch 72/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9956 - loss: 0.0858
# Epoch 73/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9960 - loss: 0.0881
# Epoch 74/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9971 - loss: 0.0840
# Epoch 75/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9881 - loss: 0.0962
# Epoch 76/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9966 - loss: 0.0798
# Epoch 77/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9964 - loss: 0.0763
# Epoch 78/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9960 - loss: 0.0722
# Epoch 79/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9961 - loss: 0.0727
# Epoch 80/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9935 - loss: 0.0763
# Epoch 81/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9934 - loss: 0.0708
# Epoch 82/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9964 - loss: 0.0652
# Epoch 83/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9962 - loss: 0.0674
# Epoch 84/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9920 - loss: 0.0677
# Epoch 85/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9958 - loss: 0.0619
# Epoch 86/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9978 - loss: 0.0549
# Epoch 87/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9945 - loss: 0.0618
# Epoch 88/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9945 - loss: 0.0584
# Epoch 89/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9952 - loss: 0.0512
# Epoch 90/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9948 - loss: 0.0551
# Epoch 91/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9974 - loss: 0.0491
# Epoch 92/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9945 - loss: 0.0528
# Epoch 93/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9945 - loss: 0.0517
# Epoch 94/100
#  1/23 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 1.0000 - loss: 0.0455
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 #fit the model
# ----> 2 model.fit(X,y,epochs=100,verbose=1)
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:320, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318 for step, iterator in epoch_iterator.enumerate_epoch():
#     319     callbacks.on_train_batch_begin(step)
# --> 320     logs = self.train_function(iterator)
#     321     callbacks.on_train_batch_end(step, logs)
#     322     if self.stop_training:
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File c:\Users\PMLS\anaconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
#determining the text
import time
seed_text = "انٹرنیٹ کے زیادہ "
next_words = 10

for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
    predicted = np.argmax(model.predict(token_list), axis=-1)
    output_word = ""
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break
    seed_text += " " + output_word
    print(seed_text)
    time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# انٹرنیٹ کے زیادہ  استعمال
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# انٹرنیٹ کے زیادہ  استعمال نے
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# انٹرنیٹ کے زیادہ  استعمال نے نوجوانوں
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# انٹرنیٹ کے زیادہ  استعمال نے نوجوانوں کی
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# انٹرنیٹ کے زیادہ  استعمال نے نوجوانوں کی ذہنی
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# انٹرنیٹ کے زیادہ  استعمال نے نوجوانوں کی ذہنی صحت
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# انٹرنیٹ کے زیادہ  استعمال نے نوجوانوں کی ذہنی صحت کو
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# انٹرنیٹ کے زیادہ  استعمال نے نوجوانوں کی ذہنی صحت کو بھی
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# انٹرنیٹ کے زیادہ  استعمال نے نوجوانوں کی ذہنی صحت کو بھی متاثر
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# انٹرنیٹ کے زیادہ  استعمال نے نوجوانوں کی ذہنی صحت کو بھی متاثر کیا
